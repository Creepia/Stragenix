# %% [markdown]
# __The first cell is defining classes and other global functions__

# %%
import os
import talib as tal
import random
import numpy as np
import pandas as pd
random.seed(42)
np.random.seed(42)


"""def get_Signal(RSI,SMA,SAR,WPR,CCI,AXD,MACD,model_path):
    model=tf.keras.models.load_model(model_path)
    test_x=pd.concat(RSI,SMA,SAR,WPR,CCI,AXD,MACD)
    for i in test_x:
        test_x[i]=test_x[i]/(test_x[i].max())
    test_x=np.reshape(test_x,test_x.shape+(1,))
    Trend=model.predict(test_x)
    Signal=pd.DataFrame(np.zeros(RSI.shape[0]))
    hasShare=0
    for i in range(RSI.shape[0]):
        # if tomorrow will up, then buy.
        if(Trend[i]==1 and hasShare==0):
            Signal[i]=1
            hasShare=1
        elif(Trend[i]==0 and hasShare==1):
            Signal[i]=2
            hasShare=0
    return Signal"""


def append_df(df, A, ignore_index=True):
    try:
        if (df.empty):
            return A
        elif (A.empty):
            return None
        else:
            return pd.concat([df, A], ignore_index=ignore_index)
    except:
        return pd.DataFrame()


# When you want to check the data after adding the indicators, you may check this variable.
debug_df=pd.DataFrame()
class TestBackModel():
    def __init__(self):
        self.backtest = pd.DataFrame()
        self.diff_list = []
        self.win_rate = 0
        self._name = "test_data"
        self.total_returns = 0
        self._signal_func_name=""

    def setBuySignals(self, df: pd.DataFrame,get_indicator_func,get_signal_func,drop_na=True):
        """
        This method will apply the indicators for df. Then set self.buy_signals as the df with only Date,Close,Signal columns.
        """
        df = self.apply_indicators_and_signal_for_data(df,get_indicator_func,get_signal_func)
        if (drop_na):
            df = df.dropna()
            df = df.reset_index(drop=True)
        global debug_df
        debug_df=df
        self.buy_signals = pd.DataFrame(df.loc[:, ["Date", "Close", "Signal"]])

    def setName(self, name: str):
        self._name = name
    def setSignalFunctionName(self, name: str):
        self._signal_func_name = name

    def setBuySignals_csv(self, filepath: str,get_indicator_func,get_signal_func, drop_na=True):
        df = pd.read_csv(filepath)
        self.setBuySignals(df=df,get_indicator_func=get_indicator_func,get_signal_func=get_signal_func,drop_na=drop_na)

    def run(self ,initial_cash=1000000,save_log=""):
        try:
            shares = 0
            position = "Hold"     # 当前仓位，默认为持仓
            equity = initial_cash  # 初始资产等于初始资金
            # 遍历每一行买入信号数据
            for _, row in self.buy_signals.iterrows():
                date = row['Date']
                close = row['Close']
                signal = row['Signal']

                if signal == 1 and shares == 0:
                    # 买入操作
                    position = "Buy"
                    shares += equity / close  # 计算可买入的股票数量
                    equity = 0  # 资金置为0，全仓买入
                elif signal == 2 and shares > 0:
                    # 卖出操作
                    position = "Sell"
                    equity += shares * close
                    shares = 0  # 持有股票数量置为0
                else:
                    position = ""
                # 将回测结果添加到数据框中
                self.backtest_row = pd.DataFrame(
                    {'Date': date, 'Close': close, 'Signal': signal, 'Position': position, 'Equity': equity}, index=[0])
                self.backtest = append_df(self.backtest, self.backtest_row)

            col_list = list(self.backtest['Equity']
                            [self.backtest['Equity'] != 0])
            col_list = [float(x) for x in col_list]
            clean_list = [col_list[0]] + [col_list[i]
                                          for i in range(1, len(col_list)) if col_list[i] != col_list[i-1]]
            self.diff_list = [clean_list[i+1] - clean_list[i]
                              for i in range(len(clean_list)-1)]
            # print([x > 0 for x in self.diff_list],self.diff_list)
            self.win_rate = sum([x > 0 for x in self.diff_list]) / len(self.diff_list)
            equity_series = self.backtest['Equity']
            last_equity = equity_series.iloc[-1]
            if last_equity == 0:
                # 循环向前查找直到找到一个非零值
                for i in range(len(equity_series) - 2, -1, -1):
                    if equity_series.iloc[i] != 0:
                        last_equity = equity_series.iloc[i]
                        break
            self.total_returns = (last_equity - initial_cash) / initial_cash
            output_data = pd.DataFrame({'backtest_length': len(self.backtest), 'diff_list_length': len(self.diff_list), 'total_returns': self.total_returns, 'win_rate': self.win_rate}, index=[self._name])
            print("Ran the backtest.")
            if(save_log):
                self.save_log(save_log)
            return (output_data)
        except Exception as e:
            print(f"{self._name} running with a error: {e}")
            return (pd.DataFrame({'backtest_length': None, 'diff_list_length': None, 'total_returns': None, 'win_rate': None}, index=[self._name]))

    def run_folder(self, folder: str, get_indicator_func,get_signal_func,signal_func_name="",initial_cash=1000000, drop_na=True,save_log="",print_output=True):
        self.setSignalFunctionName(signal_func_name)
        output=pd.DataFrame({'backtest_length': None, 'diff_list_length': None, 'total_returns': None, 'win_rate': None}, index=[""])
        output.to_csv(folder+f"/total_output_"+self._signal_func_name+".csv",mode="w")
        for file_path in os.listdir(folder):
            if ("output" in file_path) or file_path[-11:]=="_result.csv" or file_path[-4:]!=".csv":
                continue
            filepath = folder + "/" + file_path
            self.setName(file_path[:-4])
            print(f"Runnning {self._name} with {self._signal_func_name}")
            try:
                self.setBuySignals_csv(filepath, get_indicator_func,get_signal_func,drop_na)
                output=self.run(initial_cash=initial_cash,save_log=save_log)
                output.to_csv(folder+f"/total_output_"+self._signal_func_name+".csv",mode="a",header=False)
                if print_output:
                    print(output)
            except Exception as e:
                print(e)
                print("Error at running the dataframe,Skip.")
            self.backtest=None
            print("====================")

    def save_log(self, folder_name):
        try:
            if (not os.path.exists(folder_name)):
                os.makedirs(folder_name)
            self.backtest.to_csv(folder_name+"/"+self._name+"_result_"+self._signal_func_name+".csv", index=False, mode="w")
            print("Output is Saved.")
        except Exception as e:
            print(f"{self._name} saving with a error: {e}")

    def apply_indicators_for_data(self,df,get_indicator_func):
        if(df.empty):
            print("Cannot find data thus failed at applying indicators")
            return df
        elif ("Close" in df):
            df=get_indicator_func(df)
        else:
            print("Cannot find data thus failed at applying indicators")
        return df
    
    def apply_signal_for_data(self,df,get_signal_func):
        if("Close" in df):
            df["Signal"]=0
            df=get_signal_func(df)
            return df

    def apply_indicators_and_signal_for_data(self,df,get_indicator_func,get_signal_func):
        """
        Parameters
        -----
        get_indicator_func\n
        get_signal_func
        The two functions both returns a complete DataFrame
        """
        df=self.apply_indicators_for_data(df=df,get_indicator_func=get_indicator_func)
        df=self.apply_signal_for_data(df=df,get_signal_func=get_signal_func)
        return df

class SignalGeneartor():
    def __init__(self, decisions={}):
        """
        decisions {str:function}.
        eg. {"RSI":get_RSI}
        """
        self.decisions = decisions

    def addDecisions(self, decisions={}):
        self.decisions = {**self.decisions, **decisions}

    def getDecisions(self):
        return self.decisions
    
    def NextDecision(self):
        for name,func in self.getDecisions().items():
            yield (name,func)


TestBack=TestBackModel()
SG=SignalGeneartor()

# %% [markdown]
# __This cell are complemental functions for indicator calculation__

# %%
def get_WPR(High, Low, Close, n):
    H_n = High.rolling(n).max()
    L_n = Low.rolling(n).min()
    return (H_n-Close)/(H_n-L_n) * 100

def get_KD(data, window=14, k=3, d=3):
    # Calculate %K
    data['L14'] = data['Low'].rolling(window=window).min()
    data['H14'] = data['High'].rolling(window=window).max()
    data['%K'] = 100*((data['Close'] - data['L14']) / (data['H14'] - data['L14']))
    # Calculate %D
    data['%D'] = data['%K'].rolling(window=d).mean()
    return data

def get_RVI(df, n=10):
    # Calculate RVI numerator
    df['RVI_Numerator'] = (df['Close'] - df['Open']) / (df['High'] - df['Low'])
    # Calculate N period SMA for RVI
    df['RVI_SMA'] = df['RVI_Numerator'].rolling(window=n).mean()
    return df

# %% [markdown]
# __The cell below is for editing__

# %%
def getIndicators(df):
    df["RSI"] = tal.RSI(df["Close"])
    df["SMA"] = tal.SMA(df["Close"])
    df["SAR"] = tal.SAR(df["High"], df["Low"], 0.02, 0.2)
    df["WPR"] = get_WPR(df["High"], df["Low"], df["Close"], 14)
    df["CCI"] = tal.CCI(df["High"], df["Low"], df["Close"], 20)
    df["ADX"] = tal.ADX(df["High"], df["Low"], df["Close"])
    _, _, df["MACD"] = tal.MACD(df["Close"], fastperiod=10, slowperiod=20, signalperiod=9)
    df=get_KD(df,window=14,k=3,d=2)
    df["-DI"]=tal.MINUS_DI(df["High"], df["Low"], df["Close"], timeperiod=14)
    df["+DI"]=tal.MINUS_DI(df["High"], df["Low"], df["Close"], timeperiod=14)
    df["ADXR"]=tal.ADXR(df["High"], df["Low"], df["Close"], timeperiod=14)
    df["MFI"]=tal.MFI(df["High"], df["Low"], df["Close"],df["Volume"] ,timeperiod=14)
    df["EMA"]=tal.EMA(np.array(df["Close"]), timeperiod = 6)
    df=get_RVI(df,n=10)
    df["OBV"] = tal.OBV(df["Close"], df['Volume'])

    return df

def RANDOM(df):
    df['Signal'] = pd.DataFrame(np.random.randint(0,3,size=(df.shape[0],1)))
    return df

def MACD(df):
    MACD=df["MACD"]
    Signal = pd.DataFrame(np.zeros(MACD.shape[0]))

    Signal[MACD < 0] = 1  # buy
    Signal[MACD > 0] = 2  # sell

    df["Signal"]=Signal
    return df

def RSI(df,perc=30):
    RSI=df["RSI"]
    Signal=pd.DataFrame(np.zeros(RSI.shape[0]))
    Signal[RSI<perc]=1 # buy
    Signal[RSI>100-perc]=2 # sell
    df["Signal"]=Signal
    return df

def EMA(df):
    EMA=df["EMA"]
    Close=df["Close"]
    Signal=pd.DataFrame(np.zeros(EMA.shape[0]))
    Signal[Close<EMA]=1
    Signal[Close>EMA]=2
    df["Signal"]=Signal
    return df

def SMA(df):
    SMA=df["SMA"]
    Close=df["Close"]
    Signal=pd.DataFrame(np.zeros(SMA.shape[0]))
    Signal[Close<SMA]=1
    Signal[Close>SMA]=2
    df["Signal"]=Signal
    return df

def MFI(df,perc=20):
    MFI=df["MFI"]
    Signal=pd.DataFrame(np.zeros(MFI.shape[0]))
    Signal[MFI<perc]=1 # buy
    Signal[MFI>100-perc]=2 # sell
    df["Signal"]=Signal
    return df

def AND_Indicator(*indi_funcs):
    def AND(df):
        sigs=[indi_func(df.copy())["Signal"] for indi_func in indi_funcs]
        Signal=pd.DataFrame(np.zeros(df.shape[0]))
        # the i_th row
        for i in range(df.shape[0]):
            # pivot is the first signal of the first indicator
            pivot=0 if sigs[0].iloc[i]==0 else sigs[0].iloc[i]
            # the j_th indicator
            for j in range(1,len(sigs)):
                if sigs[j].iloc[i]!=pivot:
                    pivot=0
                    break
            Signal.iloc[i]=pivot
        df["Signal"]=Signal
        return df
    return AND

# %% [markdown]
# __This cell is just for running__

# %%
"""    # "MFI":MFI,
    # "RSI20":lambda x:RSI(x,perc=20),
    # "RSI30":RSI,
    # "RSI50":lambda x:RSI(x,perc=50),
    # "MACD_10_20":MACD,
    # "EMA":EMA,
    #"SMA":SMA,
    "MFIandMACD_10_20":AND_Indicator(MFI,MACD),
    "MFIandRSI30":AND_Indicator(MFI,RSI),
    "MFIandRSI50":AND_Indicator(MFI,lambda x:RSI(x,perc=50)),
    "MFIandMACD_10_20":AND_Indicator(MFI,MACD),
    "MFIandEMA":AND_Indicator(MFI,EMA),
    "MFIandSMA":AND_Indicator(MFI,SMA),
    "RSI30andMACD_10_20":AND_Indicator(lambda x:RSI(x,perc=30),MACD),
    "RSI30andEMA":AND_Indicator(lambda x:RSI(x,perc=30),EMA),
    #"RSI30andSMA":AND_Indicator(lambda x:RSI(x,perc=30),SMA),
    "RSI50andMACD_10_20":AND_Indicator(lambda x:RSI(x,perc=50),MACD),
    #"RSI50andEMA":AND_Indicator(lambda x:RSI(x,perc=50),EMA),
    #"RSI50andSMA":AND_Indicator(lambda x:RSI(x,perc=50),SMA),
    "EMAandSMA":AND_Indicator(EMA,SMA),
    "MACD_10_20andRSI50andEMA":AND_Indicator(MACD,lambda x:RSI(x,perc=50),EMA),
    "MACD_10_20andRSI50andSMA":AND_Indicator(MACD,lambda x:RSI(x,perc=50),SMA),
    "MACD_10_20andRSI30andEMA":AND_Indicator(MACD,lambda x:RSI(x,perc=30),EMA),
    "MACD_10_20andRSI30andEMA":AND_Indicator(MACD,lambda x:RSI(x,perc=30),EMA),
    "MACD_10_20andRSI50andEMAandSMA":AND_Indicator(MACD,lambda x:RSI(x,perc=50),EMA,SMA), """
SG.addDecisions({
    "Random":RANDOM
    })

# Plz Ensure that there is only original data files in the folder! Run ALL code at a time!
folder="sp500"
for name,decifunc in SG.NextDecision():
    TestBack.run_folder(
        folder=folder,
        save_log=f"{folder}/{name}",
        signal_func_name=name,
        get_indicator_func=getIndicators,
        get_signal_func=decifunc,
        initial_cash=1000000
        )
# Out:
# Runnning A with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# A             5243               886      -0.717171  0.521445
# ====================
# Runnning AAL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AAL             3801               646          1.008   0.49226
# ====================
# Runnning AAP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AAP             4764               803       6.350824  0.537983
# ====================
# Runnning AAPL with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AAPL             5242               892       9.966824  0.550448
# ====================
# Runnning ABBV with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ABBV             1973               328        0.83335  0.536585
# ====================
# Runnning ABC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ABC             5242               882       0.371533  0.538549
# ====================
# Runnning ABMD with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ABMD             5222               880       5.371117  0.523864
# ====================
# Runnning ABT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ABT             5242               859       0.441629  0.518044
# ====================
# Runnning ACN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ACN             4853               812       8.629561   0.55665
# ====================
# Runnning ADBE with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ADBE             5242               877        7.64336  0.540479
# ====================
# Runnning ADI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ADI             5242               865        0.07567  0.527168
# ====================
# Runnning ADM with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ADM             5242               890       0.292081  0.510112
# ====================
# Runnning ADP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ADP             5242               851       2.715063  0.525264
# ====================
# Runnning ADSK with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ADSK             5242               868      35.240027  0.569124
# ====================
# Runnning AEE with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AEE             5242               859       0.834003  0.543655
# ====================
# Runnning AEP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AEP             5242               863       0.262674  0.541136
# ====================
# Runnning AES with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AES             5242               848       0.579994  0.522406
# ====================
# Runnning AFL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AFL             5242               870       5.194999  0.534483
# ====================
# Runnning AIG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AIG             5242               870      -0.971506  0.495402
# ====================
# Runnning AIZ with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AIZ             4215               691       1.910483  0.562952
# ====================
# Runnning AJG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AJG             5242               865        1.09406  0.531792
# ====================
# Runnning AKAM with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AKAM             5242               880      -0.990536  0.504545
# ====================
# Runnning ALB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ALB             5242               890       2.422383  0.547191
# ====================
# Runnning ALGN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ALGN             4971               793       2.587348  0.519546
# ====================
# Runnning ALK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ALK             5242               875      24.923966  0.537143
# ====================
# Runnning ALL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ALL             5242               833       3.705734  0.521008
# ====================
# Runnning ALLE with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ALLE             1751               282       0.940524  0.542553
# ====================
# Runnning AMAT with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AMAT             5242               840       0.339301  0.520238
# ====================
# Runnning AMCR with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AMCR              384                55      -0.057027  0.545455
# ====================
# Runnning AMD with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AMD             5232               858       8.190317  0.517483
# ====================
# Runnning AME with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AME             5242               875       2.082457  0.525714
# ====================
# Runnning AMGN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AMGN             5242               856       0.496652  0.502336
# ====================
# Runnning AMP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AMP             3809               634       1.070471  0.528391
# ====================
# Runnning AMT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AMT             5242               876       1.339017  0.538813
# ====================
# Runnning AMZN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AMZN             5242               888       24.83502  0.525901
# ====================
# Runnning ANET with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ANET             1614               293       0.071882  0.546075
# ====================
# Runnning ANSS with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ANSS             5232               875      23.847039     0.544
# ====================
# Runnning ANTM with Random
# Cannot find data thus failed at applying indicators
# ANTM running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# ANTM            None             None          None     None
# ====================
# Runnning AON with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AON             5242               855        1.35275  0.555556
# ====================
# Runnning AOS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AOS             5242               861        0.02275  0.537747
# ====================
# Runnning APA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# APA             5242               890       2.005424  0.531461
# ====================
# Runnning APD with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# APD             5242               892         2.6196   0.53139
# ====================
# Runnning APH with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# APH             5242               859       2.466941  0.514552
# ====================
# Runnning APTV with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# APTV             2253               392       0.705422  0.535714
# ====================
# Runnning ARE with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ARE             5242               873      -0.173552  0.532646
# ====================
# Runnning ATO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ATO             5242               885       0.125033  0.529944
# ====================
# Runnning ATVI with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ATVI             5242               863      13.719334  0.555041
# ====================
# Runnning AVB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AVB             5242               863       0.490597  0.534183
# ====================
# Runnning AVGO with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# AVGO             2830               477       0.924411  0.501048
# ====================
# Runnning AVY with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AVY             5242               840       0.144577  0.504762
# ====================
# Runnning AWK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AWK             3155               510       4.095018  0.586275
# ====================
# Runnning AXP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AXP             5242               876       6.571671  0.531963
# ====================
# Runnning AZO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# AZO             5242               870       3.716626  0.535632
# ====================
# Runnning BA with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# BA             5242               884        1.70732  0.523756
# ====================
# Runnning BAC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BAC             5242               850       1.638754  0.537647
# ====================
# Runnning BAX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BAX             5242               874       2.941209  0.556064
# ====================
# Runnning BBWI with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# BBWI             5242               885       6.187821  0.535593
# ====================
# Runnning BBY with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BBY             5242               852      -0.226858  0.534038
# ====================
# Runnning BDX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BDX             5242               861       1.974657  0.535424
# ====================
# Runnning BEN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BEN             5242               895       0.606292  0.519553
# ====================
# Runnning BF-B with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# BF-B             5242               833       0.839637  0.518607
# ====================
# Runnning BIIB with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# BIIB             5221               875       5.855378  0.532571
# ====================
# Runnning BIO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BIO             5232               871        0.13185  0.507463
# ====================
# Runnning BK with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# BK             5242               879       0.227617  0.519909
# ====================
# Runnning BKNG with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# BKNG             5242               880       2.668693  0.538636
# ====================
# Runnning BKR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BKR             5232               841      -0.022021  0.499405
# ====================
# Runnning BLK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BLK             5242               870       4.273424  0.537931
# ====================
# Runnning BLL with Random
# Cannot find data thus failed at applying indicators
# BLL running with a error: 'NoneType' object is not subscriptable
#     backtest_length diff_list_length total_returns win_rate
# BLL            None             None          None     None
# ====================
# Runnning BMY with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BMY             5242               890      -0.388066   0.48427
# ====================
# Runnning BR with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# BR             3429               564       3.521231  0.549645
# ====================
# Runnning BRK-B with Random
# Ran the backtest.
# Output is Saved.
#        backtest_length  diff_list_length  total_returns  win_rate
# BRK-B             5242               848       3.038989  0.524764
# ====================
# Runnning BRO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BRO             5232               850       2.295121  0.541176
# ====================
# Runnning BSX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BSX             5242               860       0.254055  0.523256
# ====================
# Runnning BWA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BWA             5242               861       1.814295  0.535424
# ====================
# Runnning BXP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# BXP             5242               862       0.005294  0.542923
# ====================
# Runnning C with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# C             5242               847      -0.723516  0.487603
# ====================
# Runnning CAG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CAG             5242               865       -0.44018  0.510983
# ====================
# Runnning CAH with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CAH             5242               869       3.584532  0.540852
# ====================
# Runnning CARR with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CARR              158                26       0.243377  0.576923
# ====================
# Runnning CAT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CAT             5242               872       1.684554  0.517202
# ====================
# Runnning CB with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# CB             5232               851      15.249051  0.544066
# ====================
# Runnning CBOE with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CBOE             2615               447       0.004247  0.519016
# ====================
# Runnning CBRE with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CBRE             4128               681       2.095338  0.538913
# ====================
# Runnning CCI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CCI             5232               851       6.865628  0.561692
# ====================
# Runnning CCL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CCL             5242               879      -0.452918  0.547213
# ====================
# Runnning CDAY with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CDAY              635               116       0.360892  0.560345
# ====================
# Runnning CDNS with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CDNS             5242               859       4.079295  0.543655
# ====================
# Runnning CDW with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CDW             1851               300       0.846099  0.563333
# ====================
# Runnning CE with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# CE             3973               653       2.311123  0.568147
# ====================
# Runnning CEG with Random
# Cannot find data thus failed at applying indicators
# CEG running with a error: 'NoneType' object is not subscriptable
#     backtest_length diff_list_length total_returns win_rate
# CEG            None             None          None     None
# ====================
# Runnning CERN with Random
# Cannot find data thus failed at applying indicators
# CERN running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# CERN            None             None          None     None
# ====================
# Runnning CF with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# CF             3833               655       1.016033  0.534351
# ====================
# Runnning CFG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CFG             1538               251       0.807783   0.52988
# ====================
# Runnning CHD with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CHD             5232               853       3.190811  0.563892
# ====================
# Runnning CHRW with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CHRW             5242               890       2.349606  0.508989
# ====================
# Runnning CHTR with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CHTR             2601               404       4.966819  0.549505
# ====================
# Runnning CI with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# CI             5242               862       0.244345  0.527842
# ====================
# Runnning CINF with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CINF             5242               869      -0.018462   0.50748
# ====================
# Runnning CL with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# CL             5242               877       0.007493  0.537058
# ====================
# Runnning CLX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CLX             5242               873       1.136339  0.531501
# ====================
# Runnning CMA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CMA             5242               878       0.497826  0.493166
# ====================
# Runnning CMCSA with Random
# Ran the backtest.
# Output is Saved.
#        backtest_length  diff_list_length  total_returns  win_rate
# CMCSA             5242               865       -0.06136  0.501734
# ====================
# Runnning CME with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CME             4507               738       9.784968   0.53794
# ====================
# Runnning CMG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CMG             3718               613       3.378866  0.533442
# ====================
# Runnning CMI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CMI             5242               844       4.995429  0.530806
# ====================
# Runnning CMS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CMS             5242               886       0.889778  0.553047
# ====================
# Runnning CNC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CNC             4736               816       2.568149  0.542892
# ====================
# Runnning CNP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CNP             5242               863       3.834547  0.582851
# ====================
# Runnning COF with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# COF             5242               927       1.446933  0.518878
# ====================
# Runnning COO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# COO             5242               907       4.507359  0.542448
# ====================
# Runnning COP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# COP             5242               882       0.232914  0.522676
# ====================
# Runnning COST with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# COST             5242               879        0.43499  0.525597
# ====================
# Runnning CPB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CPB             5242               835       2.319875  0.532934
# ====================
# Runnning CPRT with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CPRT             5242               903       8.562494  0.547065
# ====================
# Runnning CRL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CRL             5112               827       1.800307  0.540508
# ====================
# Runnning CRM with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CRM             4120               719       7.499794   0.54242
# ====================
# Runnning CSCO with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CSCO             5242               893      -0.492836  0.524076
# ====================
# Runnning CSX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CSX             5242               867       2.582467  0.519031
# ====================
# Runnning CTAS with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CTAS             5242               863       0.431868  0.536501
# ====================
# Runnning CTLT with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CTLT             1576               256       1.683931  0.574219
# ====================
# Runnning CTRA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CTRA             5242               862       0.938026  0.513921
# ====================
# Runnning CTSH with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CTSH             5242               877      35.395823  0.553022
# ====================
# Runnning CTVA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# CTVA              364                61       0.179893  0.590164
# ====================
# Runnning CTXS with Random
# Cannot find data thus failed at applying indicators
# CTXS running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# CTXS            None             None          None     None
# ====================
# Runnning CVS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CVS             5242               896       0.196386  0.504464
# ====================
# Runnning CVX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CVX             5242               867      -0.435345  0.523645
# ====================
# Runnning CZR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# CZR             1520               250       0.385941     0.496
# ====================
# Runnning D with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# D             5242               843       0.551714  0.531435
# ====================
# Runnning DAL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DAL             3400               561       0.996765  0.500891
# ====================
# Runnning DD with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# DD             5242               861       1.597664  0.519164
# ====================
# Runnning DE with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# DE             5242               879       0.979792  0.527873
# ====================
# Runnning DFS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DFS             3371               542       0.588503  0.555351
# ====================
# Runnning DG with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# DG             2760               476       8.933282  0.567227
# ====================
# Runnning DGX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DGX             5242               871      10.180694  0.541906
# ====================
# Runnning DHI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DHI             5242               875       3.007978  0.515429
# ====================
# Runnning DHR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DHR             5242               866       9.736179  0.561201
# ====================
# Runnning DIS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DIS             5242               874       1.650792   0.51373
# ====================
# Runnning DISCA with Random
# Cannot find data thus failed at applying indicators
# DISCA running with a error: 'NoneType' object is not subscriptable
#       backtest_length diff_list_length total_returns win_rate
# DISCA            None             None          None     None
# ====================
# Runnning DISCK with Random
# Cannot find data thus failed at applying indicators
# DISCK running with a error: 'NoneType' object is not subscriptable
#       backtest_length diff_list_length total_returns win_rate
# DISCK            None             None          None     None
# ====================
# Runnning DISH with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# DISH             5242               870      -0.501942  0.510345
# ====================
# Runnning DLR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DLR             4030               679       1.306165  0.544919
# ====================
# Runnning DLTR with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# DLTR             5242               853       1.278499  0.531067
# ====================
# Runnning DOV with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DOV             5242               877        1.25322  0.554162
# ====================
# Runnning DOW with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DOW              410                73      -0.093791  0.465753
# ====================
# Runnning DPZ with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DPZ             4107               685       6.705813  0.548905
# ====================
# Runnning DRE with Random
# Cannot find data thus failed at applying indicators
# DRE running with a error: 'NoneType' object is not subscriptable
#     backtest_length diff_list_length total_returns win_rate
# DRE            None             None          None     None
# ====================
# Runnning DRI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DRI             5242               863       4.829358  0.524913
# ====================
# Runnning DTE with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DTE             5242               865        0.52169  0.534104
# ====================
# Runnning DUK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DUK             5242               867       1.019027  0.560554
# ====================
# Runnning DVA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DVA             5242               863      18.362773  0.526072
# ====================
# Runnning DVN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DVN             5242               874      -0.857576  0.497712
# ====================
# Runnning DXC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# DXC             5242               870      -0.216012  0.536782
# ====================
# Runnning DXCM with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# DXCM             3906               642       8.491172   0.52648
# ====================
# Runnning EA with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# EA             5242               861      -0.094523  0.509872
# ====================
# Runnning EBAY with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EBAY             5242               859       0.296386  0.513388
# ====================
# Runnning ECL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ECL             5242               858       2.523803  0.560606
# ====================
# Runnning ED with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# ED             5242               848       3.228425  0.564858
# ====================
# Runnning EFX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EFX             5242               855       1.801746   0.54269
# ====================
# Runnning EIX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EIX             5242               851      -0.227844  0.526439
# ====================
# Runnning EL with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# EL             5242               874       4.020222  0.534325
# ====================
# Runnning EMN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EMN             5242               909       2.107267  0.529153
# ====================
# Runnning EMR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EMR             5242               875       1.826281  0.515429
# ====================
# Runnning ENPH with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ENPH             2162               358       1.668141  0.527933
# ====================
# Runnning EOG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EOG             5242               873       1.389813  0.521191
# ====================
# Runnning EPAM with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EPAM             2198               384       6.634562  0.559896
# ====================
# Runnning EQIX with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EQIX             5088               847       -0.17108    0.5183
# ====================
# Runnning EQR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EQR             5232               844        0.53915  0.524882
# ====================
# Runnning ES with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# ES             5242               868       1.280376   0.53341
# ====================
# Runnning ESS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ESS             5242               887       0.940003  0.564825
# ====================
# Runnning ETN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ETN             5232               861         0.6753  0.512195
# ====================
# Runnning ETR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ETR             5242               892      -0.037252  0.522422
# ====================
# Runnning ETSY with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ETSY             1398               216      27.061604  0.587963
# ====================
# Runnning EVRG with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EVRG             5242               848      -0.651824  0.529481
# ====================
# Runnning EW with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# EW             5184               838       1.761479  0.550119
# ====================
# Runnning EXC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EXC             5242               885       0.226528  0.538983
# ====================
# Runnning EXPD with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EXPD             5242               838       3.188387  0.550119
# ====================
# Runnning EXPE with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# EXPE             3848               629       1.125472  0.540541
# ====================
# Runnning EXR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# EXR             4083               692       4.217363  0.554913
# ====================
# Runnning F with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# F             5242               857      -0.627966  0.490082
# ====================
# Runnning FANG with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FANG             2026               344      -0.118071  0.531977
# ====================
# Runnning FAST with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FAST             5242               860       1.223553   0.52093
# ====================
# Runnning FB with Random
# Cannot find data thus failed at applying indicators
# FB running with a error: 'NoneType' object is not subscriptable
#    backtest_length diff_list_length total_returns win_rate
# FB            None             None          None     None
# ====================
# Runnning FBHS with Random
# Cannot find data thus failed at applying indicators
# FBHS running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# FBHS            None             None          None     None
# ====================
# Runnning FCX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FCX             5242               891      15.418675  0.531987
# ====================
# Runnning FDS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FDS             5242               859       1.740168  0.540163
# ====================
# Runnning FDX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FDX             5242               893       0.636766  0.525196
# ====================
# Runnning FE with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# FE             5242               886       0.124732  0.540632
# ====================
# Runnning FFIV with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FFIV             5242               857       0.163249  0.506418
# ====================
# Runnning FIS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FIS             4873               816       1.417286  0.541667
# ====================
# Runnning FISV with Random
# Cannot find data thus failed at applying indicators
# FISV running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# FISV            None             None          None     None
# ====================
# Runnning FITB with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FITB             5242               859      -0.176337  0.507567
# ====================
# Runnning FLT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FLT             2487               421       4.171821  0.586698
# ====================
# Runnning FMC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FMC             5242               879       1.501772  0.554039
# ====================
# Runnning FOX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FOX              415                69       0.221732   0.57971
# ====================
# Runnning FOXA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FOXA              416                79       0.148717  0.518987
# ====================
# Runnning FRC with Random
# Cannot find data thus failed at applying indicators
# FRC running with a error: 'NoneType' object is not subscriptable
#     backtest_length diff_list_length total_returns win_rate
# FRC            None             None          None     None
# ====================
# Runnning FRT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FRT             5242               906       -0.41751   0.52649
# ====================
# Runnning FTNT with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# FTNT             2757               443       2.475497  0.548533
# ====================
# Runnning FTV with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# FTV             1091               181       0.599265   0.59116
# ====================
# Runnning GD with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# GD             5242               848       0.525416  0.550708
# ====================
# Runnning GE with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# GE             5242               875       0.969043  0.498286
# ====================
# Runnning GILD with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# GILD             5221               859        6.88078  0.527357
# ====================
# Runnning GIS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# GIS             5242               855      -0.342424  0.492398
# ====================
# Runnning GL with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# GL             5242               867        2.35732   0.54902
# ====================
# Runnning GLW with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# GLW             5242               869       -0.68205  0.506329
# ====================
# Runnning GM with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# GM             2505               419      -0.059141   0.49642
# ====================
# Runnning GNRC with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# GNRC             2700               445       0.180655  0.510112
# ====================
# Runnning GOOG with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# GOOG             4080               668       2.960052  0.564371
# ====================
# Runnning GOOGL with Random
# Ran the backtest.
# Output is Saved.
#        backtest_length  diff_list_length  total_returns  win_rate
# GOOGL             4080               710       9.947603   0.55493
# ====================
# Runnning GPC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# GPC             5242               824       0.458076  0.519417
# ====================
# Runnning GPN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# GPN             4981               840       5.248613  0.544048
# ====================
# Runnning GRMN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# GRMN             5005               830       0.884051  0.550602
# ====================
# Runnning GS with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# GS             5242               886       0.722993  0.511287
# ====================
# Runnning GWW with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# GWW             5242               859       0.115657   0.50291
# ====================
# Runnning HAL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HAL             5242               893      -0.231144  0.516237
# ====================
# Runnning HAS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HAS             5242               875        0.56941  0.509714
# ====================
# Runnning HBAN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# HBAN             5242               873      -0.170279  0.482245
# ====================
# Runnning HCA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HCA             2429               408       0.155997  0.517157
# ====================
# Runnning HD with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# HD             5242               859       0.908091  0.533178
# ====================
# Runnning HES with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HES             5242               867       0.297588  0.520185
# ====================
# Runnning HIG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HIG             5242               853      17.949316  0.545135
# ====================
# Runnning HII with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HII             2421               406       0.048535  0.524631
# ====================
# Runnning HLT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# HLT             1734               303      -0.232863   0.49505
# ====================
# Runnning HOLX with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# HOLX             5242               875       3.389623  0.530286
# ====================
# Runnning HON with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ...
# Runnning SYK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# SYK             5242               883        6.40008  0.556059
# ====================
# Runnning SYY with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# SYY             5232               861      -0.091649  0.541231
# ====================
# Runnning T with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# T             5242               906       0.089627  0.504415
# ====================
# Runnning TAP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TAP             5242               847       0.791529  0.512397
# ====================
# Runnning TDG with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TDG             3685               607          7.541  0.550247
# ====================
# Runnning TDY with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TDY             5242               875      17.436591  0.539429
# ====================
# Runnning TECH with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TECH             5242               886       0.364423  0.518059
# ====================
# Runnning TEL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TEL             3371               555       1.793149  0.547748
# ====================
# Runnning TER with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TER             5242               873        0.56728  0.526919
# ====================
# Runnning TFC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TFC             5242               883       4.863773  0.524349
# ====================
# Runnning TFX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TFX             5242               869       2.766406   0.55351
# ====================
# Runnning TGT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TGT             5242               897       2.730177  0.525084
# ====================
# Runnning TJX with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TJX             5242               855      12.083695  0.575439
# ====================
# Runnning TMO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TMO             5242               845       9.320832  0.540828
# ====================
# Runnning TMUS with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TMUS             3410               562       0.150142  0.544484
# ====================
# Runnning TPR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TPR             5049               833       7.159055  0.523409
# ====================
# Runnning TRMB with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TRMB             5242               879      -0.167228  0.526735
# ====================
# Runnning TROW with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TROW             5242               882       6.154241  0.540816
# ====================
# Runnning TRV with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TRV             5242               874       1.818098  0.536613
# ====================
# Runnning TSCO with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TSCO             5200               902       1.440269  0.508869
# ====================
# Runnning TSLA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TSLA             2605               417       9.877865  0.517986
# ====================
# Runnning TSN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TSN             5242               864       1.205685  0.524306
# ====================
# Runnning TT with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# TT             5242               872       2.085252  0.545872
# ====================
# Runnning TTWO with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# TTWO             5216               861       1.306006  0.519164
# ====================
# Runnning TWTR with Random
# Cannot find data thus failed at applying indicators
# TWTR running with a error: 'NoneType' object is not subscriptable
#      backtest_length diff_list_length total_returns win_rate
# TWTR            None             None          None     None
# ====================
# Runnning TXN with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TXN             5242               846      -0.422857  0.527187
# ====================
# Runnning TXT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TXT             5242               864       2.171486  0.517361
# ====================
# Runnning TYL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# TYL             5214               845      27.006065  0.532544
# ====================
# Runnning UA with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# UA             1162               185      -0.672769  0.459459
# ====================
# Runnning UAA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UAA             3763               635      -0.599704  0.502362
# ====================
# Runnning UAL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UAL             3711               625      -0.783088    0.5216
# ====================
# Runnning UDR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UDR             5242               825       1.025875  0.552727
# ====================
# Runnning UHS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UHS             5242               856       1.781482  0.536215
# ====================
# Runnning ULTA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ULTA             3278               516       0.393483  0.531008
# ====================
# Runnning UNH with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UNH             5242               866      16.029681   0.54388
# ====================
# Runnning UNP with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UNP             5242               859       12.30325  0.548312
# ====================
# Runnning UPS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# UPS             5242               877       0.248036  0.510832
# ====================
# Runnning URI with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# URI             5242               858       1.479802  0.516317
# ====================
# Runnning USB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# USB             5242               870       0.388642  0.516092
# ====================
# Runnning V with Random
# Ran the backtest.
# Output is Saved.
#    backtest_length  diff_list_length  total_returns  win_rate
# V             3179               529       3.402737  0.597353
# ====================
# Runnning VFC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# VFC             5242               839      12.674239  0.524434
# ====================
# Runnning VLO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# VLO             5242               827       8.649193  0.527207
# ====================
# Runnning VMC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# VMC             5242               880       0.888947  0.493182
# ====================
# Runnning VNO with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# VNO             5242               872       2.281779  0.510321
# ====================
# Runnning VRSK with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# VRSK             2787               461       3.598913  0.563991
# ====================
# Runnning VRSN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# VRSN             5242               885      -0.717013  0.542373
# ====================
# Runnning VRTX with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# VRTX             5222               870      -0.347291  0.487356
# ====================
# Runnning VTR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# VTR             5227               875       4.890821  0.538286
# ====================
# Runnning VTRS with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# VTRS             5242               878      -0.460296  0.496583
# ====================
# Runnning VZ with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# VZ             5242               865      -0.470105  0.509827
# ====================
# Runnning WAB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WAB             5242               886       0.183011  0.539503
# ====================
# Runnning WAT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WAT             5242               858       1.735066   0.54662
# ====================
# Runnning WBA with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WBA             5242               906      -0.526624       0.5
# ====================
# Runnning WDC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WDC             5242               879       0.101649  0.523322
# ====================
# Runnning WEC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WEC             5242               847       2.469125  0.553719
# ====================
# Runnning WELL with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# WELL             5242               881        0.72054  0.549376
# ====================
# Runnning WFC with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WFC             5242               854      -0.551995  0.490632
# ====================
# Runnning WHR with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WHR             5232               875       0.866767  0.522286
# ====================
# Runnning WM with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# WM             5242               892       2.131164  0.522422
# ====================
# Runnning WMB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WMB             5242               850      -0.672185  0.516471
# ====================
# Runnning WMT with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WMT             5242               890       1.954384  0.537079
# ====================
# Runnning WRB with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WRB             5242               889      13.194559  0.563555
# ====================
# Runnning WRK with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WRK             1350               224      -0.284116  0.508929
# ====================
# Runnning WST with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WST             5227               868       2.906936  0.520737
# ====================
# Runnning WTW with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# WTW             4869               801       3.525701  0.534332
# ====================
# Runnning WY with Random
# Ran the backtest.
# Output is Saved.
#     backtest_length  diff_list_length  total_returns  win_rate
# WY             5242               871       0.305706  0.515499
# ====================
# Runnning WYNN with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# WYNN             4536               755       2.047776  0.521854
# ====================
# Runnning XEL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# XEL             5232               874      -0.681762  0.505721
# ====================
# Runnning XOM with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# XOM             5242               870       1.745523  0.522989
# ====================
# Runnning XRAY with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# XRAY             5242               861       0.681195  0.536585
# ====================
# Runnning XYL with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# XYL             2278               386       2.819927  0.585492
# ====================
# Runnning YUM with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# YUM             5242               901       7.764018   0.54273
# ====================
# Runnning ZBH with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ZBH             4849               811       1.431974  0.551171
# ====================
# Runnning ZBRA with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ZBRA             5242               865       2.234063  0.515607
# ====================
# Runnning ZION with Random
# Ran the backtest.
# Output is Saved.
#       backtest_length  diff_list_length  total_returns  win_rate
# ZION             5242               872        0.21447  0.527523
# ====================
# Runnning ZTS with Random
# Ran the backtest.
# Output is Saved.
#      backtest_length  diff_list_length  total_returns  win_rate
# ZTS             1952               337       1.814797  0.563798
# ====================

# %%
print(TestBack.backtest)
pd.DataFrame(np.random.randint(0,3,size=(debug_df.shape[0],1)))
# Out:
# None
#       0
# 0     0
# 1     2
# 2     0
# 3     1
# 4     0
# ...  ..
# 1948  0
# 1949  1
# 1950  0
# 1951  1
# 1952  2
#
# [1953 rows x 1 columns]
